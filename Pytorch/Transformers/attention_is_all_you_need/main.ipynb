# %%
from data import load_tokenizers
from data import load_vocab
import torchtext
torchtext.disable_torchtext_deprecation_warning()
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
spacy_en, spacy_de = load_tokenizers()
tokens_en = [tok.text for tok in spacy_en("I love transformers")]
tokens_de = [tok.text for tok in spacy_de("Hallo Ich bin gut")]
print(tokens_en)
print(tokens_de)
# Out:
# ['I', 'love', 'transformers']
# ['Hallo', 'Ich', 'bin', 'gut']

# %%
vocab_src, vocab_tgt = load_vocab(spacy_de, spacy_en)
# Out:
# Finished.
# Vocabulary sizes:
# 5632
# 7010

# %%
print(vocab_src["love"])
print(vocab_tgt["transformers"])

""""
I -> 0
"love" -> 1
"transformers" -> 2
"are" -> 3
"powerful" -> 4
"NLP" -> 5
"""
# Out:
# 2498
# 3
# '"\nI -> 0\n"love" -> 1\n"transformers" -> 2\n"are" -> 3\n"powerful" -> 4\n"NLP" -> 5\n'
