# %%
from data import load_tokenizers


spacy_en, spacy_de = load_tokenizers()
tokens = [tok.text for tok in spacy_en("I love transformers")]
print(tokens)
# Out:
# ['I', 'love', 'transformers']
