# %%
#PASCAL segmentation is 21 classes
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from utils import extract_photo

# %%
img = extract_photo(filename="./images/", number_to_Show=20)
fig, arr = plt.subplots(1, 2, figsize=(14, 10))
arr[0].imshow(img)
arr[0].set_title('Image')
# Out:
# Text(0.5, 1.0, 'Image')
